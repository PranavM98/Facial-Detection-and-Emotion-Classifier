# %% [markdown]
# ##Data

# %%
# !git clone https://github.com/PranavM98/Facial-Detection-and-Emotion-Classifier.git
# Out:
# Cloning into 'Facial-Detection-and-Emotion-Classifier'...
# remote: Enumerating objects: 87265, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 87265 (delta 28), reused 46 (delta 19), pack-reused 87206
# Receiving objects: 100% (87265/87265), 342.52 MiB | 32.42 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# Checking out files: 100% (134158/134158), done.

# %%
import glob
import os

# %%
'''
for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/angry/*"):
  name=file.rfind("/")
    # Absolute path of a file
  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/angry/"+file[name+1:]
  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/angry/angry_"+file[name+1:]

  # Renaming the file
  os.rename(old_name, new_name)


for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/disgust/*"):
  name=file.rfind("/")
    # Absolute path of a file
  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/disgust/"+file[name+1:]
  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/disgust/disgust_"+file[name+1:]

  # Renaming the file
  os.rename(old_name, new_name)


for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/fear/*"):
  name=file.rfind("/")
    # Absolute path of a file
  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/fear/"+file[name+1:]
  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/fear/fear_"+file[name+1:]

  # Renaming the file
  os.rename(old_name, new_name)


for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/happy/*"):
  name=file.rfind("/")
    # Absolute path of a file
  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/happy/"+file[name+1:]
  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/happy/happy_"+file[name+1:]

  # Renaming the file
  os.rename(old_name, new_name)




for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/neutral/*"):
  name=file.rfind("/")
    # Absolute path of a file
  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/neutral/"+file[name+1:]
  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/neutral/neutral_"+file[name+1:]

  # Renaming the file
  os.rename(old_name, new_name)



for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/sad/*"):
  name=file.rfind("/")
    # Absolute path of a file
  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/sad/"+file[name+1:]
  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/sad/sad_"+file[name+1:]

  # Renaming the file
  os.rename(old_name, new_name)




for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/surprise/*"):
  name=file.rfind("/")
    # Absolute path of a file
  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/surprise/"+file[name+1:]
  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/surprise/surprise_"+file[name+1:]

  # Renaming the file
  os.rename(old_name, new_name)




'''
# Out:
# '\nfor file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/angry/*"):\n  name=file.rfind("/")\n    # Absolute path of a file\n  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/angry/"+file[name+1:]\n  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/angry/angry_"+file[name+1:]\n\n  # Renaming the file\n  os.rename(old_name, new_name)\n\n\nfor file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/disgust/*"):\n  name=file.rfind("/")\n    # Absolute path of a file\n  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/disgust/"+file[name+1:]\n  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/disgust/disgust_"+file[name+1:]\n\n  # Renaming the file\n  os.rename(old_name, new_name)\n\n\nfor file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/fear/*"):\n  name=file.rfind("/")\n    # Absolute path of a file\n  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/fear/"+file[name+1:]\n  new_name = r"../../00_Data/00_Source_Da
# ...

# %%
'''
for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/neutral/*"):
  name=file.rfind("/")
    # Absolute path of a file
  old_name = r"../../00_Data/00_Source_Data/Emotion_Images/neutral/"+file[name+1:]
  new_name = r"../../00_Data/00_Source_Data/Emotion_Images/neutral/neutral_"+file[name+1:]

  # Renaming the file
  os.rename(old_name, new_name)
  '''

# %%
import pandas as pd

final_lst=[]
for file in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/*"):
    lst=[]
    name=file.rfind("/")
    string=file[name+1:]
    under=string.find("_")
    string1=string[:under]
    print(string1)
    lst=[string,string1]
    final_lst.append(lst)

data=pd.DataFrame(final_lst, columns=['Filename','label'])
# Out:
# happy
# happy
# fear
# neutral
# happy
# angry
# sad
# happy
# neutral
# sad
# fear
# happy
# surprise
# sad
# neutral
# neutral
# happy
# neutral
# fear
# sad
# angry
# fear
# neutral
# fear
# happy
# angry
# surprise
# happy
# neutral
# surprise
# angry
# sad
# happy
# happy
# angry
# happy
# fear
# surprise
# happy
# surprise
# surprise
# neutral
# fear
# angry
# sad
# surprise
# sad
# happy
# angry
# happy
# neutral
# angry
# happy
# happy
# sad
# happy
# surprise
# angry
# happy
# sad
# sad
# surprise
# happy
# surprise
# sad
# happy
# sad
# angry
# surprise
# surprise
# sad
# fear
# fear
# neutral
# angry
# neutral
# sad
# neutral
# happy
# surprise
# sad
# sad
# happy
# angry
# fear
# surprise
# happy
# angry
# happy
# sad
# happy
# happy
# happy
# angry
# surprise
# sad
# angry
# disgust
# happy
# sad
# happy
# fear
# angry
# fear
# happy
# surprise
# sad
# happy
# happy
# fear
# sad
# angry
# happy
# surprise
# surprise
# sad
# neutral
# neutral
# happy
# sad
# neutral
# ...

# %%
_=data.to_csv("../../00_Data/01_Transformed_Data/emotion_label.csv")

# %%
import os
import glob
from PIL import Image
for filename in glob.glob("../../00_Data/00_Source_Data/Emotion_Images/*"):
    try:
        img=Image.open(filename)
        re_img=img.resize((250,250))
        
        
        name=filename[filename.rfind("/")+1:]
        new_file="../../00_Data/01_Transformed_Data/Resized_Emotion_Images/"+name
        re_img.save(new_file)

    except:
        continue

# %% [markdown]
# ## Data Preprocessing

# %%
import tensorflow as tf
import numpy as np
from numpy.random import randn
import pathlib
import random
from PIL import Image
import cv2
from matplotlib.image import imread
from keras.preprocessing import image
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_dir = pathlib.Path("/content/Facial-Detection-and-Emotion-Classifier/00_Data/01_Transformed_Data/Resized_Emotion_Images/")

# %%
label_names={'happy':0,
            'sad':1,
            'neutral':2
}

# %%
img_data=[]
count=0
all_images = list(data_dir.glob('*'))
all_labels=[]
kernel = np.array([[0, -1, 0],
              [-1, 5,-1],
              [0, -1, 0]])

wrong_emotion=['disgust','fear','surprise','fea','angry']
for i in all_images:
  a=str(i)[str(i).rfind('/')+1:]
  emotion=a[:a.find('_')]

  if emotion not in wrong_emotion :
    img=Image.open(str(i))
    img=img.resize((64,64))
    img=np.array(img).astype('float64')
    #img = cv2.filter2D(src=img, ddepth=-1, kernel=kernel)
    img=img/255
    img_data.append(img)

# %%
#Augmented Data
from google.colab.patches import cv2_imshow

'''
Sharpening the Image by convolving with the filter

'''
kernel = np.array([[0, -1, 0],
              [-1, 5,-1],
              [0, -1, 0]])

aug_img_data=[]
for i in img_data:
  image_sharp = cv2.filter2D(src=i, ddepth=-1, kernel=kernel)
  aug_img_data.append(image_sharp)

# %%
data=pd.read_csv("/content/Facial-Detection-and-Emotion-Classifier/00_Data/01_Transformed_Data/emotion_label.csv")

all_images = list(data_dir.glob('*'))
all_labels=[]
for i in all_images:
  file=str(i)[str(i).rfind('/')+1:]
  
  a=str(i)[str(i).rfind('/')+1:]
  emotion=a[:a.find('_')]

  if emotion not in wrong_emotion:
    all_labels.append(label_names[data[data['Filename']==file]['label'].values[0]])

# %%
pd.Series(all_labels).value_counts()
# Out:
# 0    8989
# 2    6198
# 1    6077
# dtype: int64

# %%
len(img_data)
tf.random.set_seed(
    5
)

# %%
#Masking
top_mask=[]
bottom_mask=[]
three_fourth_mask=[]
def creating_mask():
    a=np.array([0]*2048)
    a=a.reshape((32,64))
    b=np.array([1]*2048)
    b=b.reshape((32,64))
    return a,b


for i in img_data:
    a,b=creating_mask()
    con_bot = np.concatenate((b,a),axis=0)
    con_top = np.concatenate((a,b),axis=0)
    #bottom_mask.append(np.multiply(con_bot,i))
    #top_mask.append(np.multiply(con_top,i))
    bottom_mask.append(i[:32,:])
    top_mask.append(i[32:,:])
    three_fourth_mask.append(i[16:,:])

# %%
import pickle

# %%
img_data[0][32:,:].shape
# Out:
# (32, 64)

# %%
#No Mask
data_size=len(all_images)

train_test_split=(int)(data_size*0.2)

x_train=img_data[train_test_split:]
x_test=img_data[:train_test_split]

y_train=all_labels[train_test_split:]
y_test=all_labels[:train_test_split]

# %%
kernel = np.array([[0, -1, 0],
              [-1, 5,-1],
              [0, -1, 0]])

aug_x_train=[]
for i in x_train:
  image_sharp = cv2.filter2D(src=i, ddepth=-1, kernel=kernel)
  aug_x_train.append(image_sharp)

# %%
len(aug_x_train)
# Out:
# 14087

# %%
final_x_train=x_train+aug_x_train
final_y_train=y_train+y_train

# %%
for i in range(len(x_train)):
    x_train[i]=x_train[i].reshape((64,64,1))


for i in range(len(x_test)):
    x_test[i]=x_test[i].reshape((64,64,1))

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((np.asarray(final_x_train), np.array(final_y_train)))
test_dataset = tf.data.Dataset.from_tensor_slices((np.asarray(x_test), np.array(y_test)))

# %%
#Bottom Mask
data_size=len(all_images)

train_test_split=(int)(data_size*0.2)

x_train_bm=bottom_mask[train_test_split:]
x_test_bm=bottom_mask[:train_test_split]

y_train_bm=all_labels[train_test_split:]
y_test_bm=all_labels[:train_test_split]

# %%
kernel = np.array([[0, -1, 0],
              [-1, 5,-1],
              [0, -1, 0]])

aug_x_train_bm=[]
for i in x_train_bm:
  image_sharp = cv2.filter2D(src=i, ddepth=-1, kernel=kernel)
  aug_x_train_bm.append(image_sharp)

# %%
final_x_train_bm=x_train_bm+aug_x_train_bm
final_y_train_bm=y_train_bm+y_train_bm

# %%
train_dataset_bm = tf.data.Dataset.from_tensor_slices((np.asarray(final_x_train_bm), np.array(final_y_train_bm)))
test_dataset_bm = tf.data.Dataset.from_tensor_slices((np.asarray(x_test_bm), np.array(y_test_bm)))

# %%
#Top Mask
data_size=len(all_images)

train_test_split=(int)(data_size*0.2)

x_train_tm=top_mask[train_test_split:]
x_test_tm=top_mask[:train_test_split]

y_train_tm=all_labels[train_test_split:]
y_test_tm=all_labels[:train_test_split]

# %%
kernel = np.array([[0, -1, 0],
              [-1, 5,-1],
              [0, -1, 0]])

aug_x_train_tm=[]
for i in x_train_tm:
  image_sharp = cv2.filter2D(src=i, ddepth=-1, kernel=kernel)
  aug_x_train_tm.append(image_sharp)

# %%
final_x_train_tm=x_train_tm+aug_x_train_tm
final_y_train_tm=y_train_tm+y_train_tm

# %%
train_dataset_tm = tf.data.Dataset.from_tensor_slices((np.asarray(final_x_train_tm), np.array(final_y_train_tm)))
test_dataset_tm = tf.data.Dataset.from_tensor_slices((np.asarray(x_test_tm), np.array(y_test_tm)))

# %%
## Three Fourth Face

data_size=len(all_images)

train_test_split=(int)(data_size*0.2)

x_train_tfm=three_fourth_mask[train_test_split:]
x_test_tfm=three_fourth_mask[:train_test_split]

y_train_tfm=all_labels[train_test_split:]
y_test_tfm=all_labels[:train_test_split]

# %%
for i in range(len(x_train)):
    x_train_tfm[i]=x_train_tfm[i].reshape((48,64))


for i in range(len(x_test)):
    x_test_tfm[i]=x_test_tfm[i].reshape((48,64))

# %%
kernel = np.array([[0, -1, 0],
              [-1, 5,-1],
              [0, -1, 0]])

aug_x_train_tfm=[]
for i in x_train_tfm:
  image_sharp = cv2.filter2D(src=i, ddepth=-1, kernel=kernel)
  aug_x_train_tfm.append(image_sharp)

# %%
final_x_train_tfm=x_train_tfm+aug_x_train_tfm
final_y_train_tfm=y_train_tfm+y_train_tfm

# %%
train_dataset_tfm = tf.data.Dataset.from_tensor_slices((np.asarray(final_x_train_tfm), np.array(final_y_train_tfm)))
test_dataset_tfm = tf.data.Dataset.from_tensor_slices((np.asarray(x_test_tfm), np.array(y_test_tfm)))

# %%
for i in final_x_train_tfm:
  if i.shape != (48,64):
    print("HI")

# %%
len(final_x_train)
# Out:
# 28174

# %%
len(final_x_train_tm)
# Out:
# 28174

# %%
len(final_x_train_bm)
# Out:
# 28174

# %%
len(final_x_train_tfm)
# Out:
# 28174

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
device_name
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## VGG-16 Model

# %%
from tensorflow.keras.layers import Input, Conv2D
from tensorflow.keras.layers import MaxPool2D, Flatten, Dense
from tensorflow.keras import Model

# %%
input = Input(shape=(64,64,1))

# %%
x=Conv2D(filters=64,kernel_size=3, padding='same',activation='relu')(input)
x=Conv2D(filters=64,kernel_size=3, padding='same',activation='relu')(x)
x=MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# %%
x=Conv2D(filters=128,kernel_size=3, padding='same', activation='relu')(x)
x=Conv2D(filters=128,kernel_size=3, padding='same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding= 'same')(x)

# %%
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)

# %%
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)

# %%
x=Flatten()(x)
x=Dense(units=4096, activation='relu')(x)
x=Dense(units=4096, activation='relu')(x)
x=Dense(units=1000, activation='relu')(x)
output=Dense(units=3, activation='softmax')(x)

# %%
model=Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_17 (InputLayer)       [(None, 64, 64, 1)]       0
#
#  conv2d_208 (Conv2D)         (None, 64, 64, 64)        640
#
#  conv2d_209 (Conv2D)         (None, 64, 64, 64)        36928
#
#  max_pooling2d_80 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_210 (Conv2D)         (None, 32, 32, 128)       73856
#
#  conv2d_211 (Conv2D)         (None, 32, 32, 128)       147584
#
#  max_pooling2d_81 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_212 (Conv2D)         (None, 16, 16, 256)       295168
#
#  conv2d_213 (Conv2D)         (None, 16, 16, 256)       590080
#
#  conv2d_214 (Conv2D)         (None, 16, 16, 256)       590080
#
#  max_pooling2d_82 (MaxPoolin  (None, 8, 8, 256)        0
#  g2D)
#
#  conv2d_215 (Conv2D)         (None, 8, 8, 512)         1180160
#
# ...

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.0001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=tf.keras.metrics.SparseCategoricalAccuracy()
)

# %%
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=25,
                                            restore_best_weights=True, mode='max')
history=model.fit(train_dataset, epochs=25, validation_data=(test_dataset),callbacks=[callback])
# Out:
# Epoch 1/25
# 441/441 [==============================] - 26s 56ms/step - loss: 0.9721 - sparse_categorical_accuracy: 0.4961 - val_loss: 0.9150 - val_sparse_categorical_accuracy: 0.5392
# Epoch 2/25
# 441/441 [==============================] - 24s 55ms/step - loss: 0.7498 - sparse_categorical_accuracy: 0.6426 - val_loss: 0.7945 - val_sparse_categorical_accuracy: 0.6122
# Epoch 3/25
# 441/441 [==============================] - 24s 55ms/step - loss: 0.6589 - sparse_categorical_accuracy: 0.6953 - val_loss: 0.8292 - val_sparse_categorical_accuracy: 0.5880
# Epoch 4/25
# 441/441 [==============================] - 24s 55ms/step - loss: 0.5809 - sparse_categorical_accuracy: 0.7415 - val_loss: 0.7382 - val_sparse_categorical_accuracy: 0.6682
# Epoch 5/25
# 441/441 [==============================] - 24s 55ms/step - loss: 0.5052 - sparse_categorical_accuracy: 0.7811 - val_loss: 0.8193 - val_sparse_categorical_accuracy: 0.6572
# Epoch 6/25
# ...

# %%
model.save("/content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/no_mask_model")
# Out:
# INFO:tensorflow:Assets written to: /content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/no_mask_model/assets

# %%
#reconstructed_model = keras.models.load_model("my_model")

# %%
y_pred=model.predict(np.asarray(x_test))
y_preds=np.argmax(y_pred,axis=1)

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report

# %%
confusion_matrix(y_test,y_preds)
# Out:
# array([[2563,  240,  235],
#        [ 199, 1452,  407],
#        [ 225,  681, 1175]])

# %%
accuracy_score(y_test,y_preds)
# Out:
# 0.7231433746690817

# %%
f1_score(y_test,y_preds,average='weighted')
# Out:
# 0.7228719000056452

# %%
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      3038
#            1       0.61      0.71      0.66      2058
#            2       0.65      0.56      0.60      2081
#
#     accuracy                           0.72      7177
#    macro avg       0.71      0.70      0.70      7177
# weighted avg       0.73      0.72      0.72      7177

# %% [markdown]
# ## Bottom Mask

# %%
train_dataset_bm = train_dataset_bm.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset_bm = test_dataset_bm.batch(BATCH_SIZE)

# %%
input = Input(shape=(32,64,1))
x=Conv2D(filters=64,kernel_size=3, padding='same',activation='relu')(input)
x=Conv2D(filters=64,kernel_size=3, padding='same',activation='relu')(x)
x=MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
x=Conv2D(filters=128,kernel_size=3, padding='same', activation='relu')(x)
x=Conv2D(filters=128,kernel_size=3, padding='same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding= 'same')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)


x=Flatten()(x)
x=Dense(units=4096, activation='relu')(x)
x=Dense(units=4096, activation='relu')(x)
x=Dense(units=1000, activation='relu')(x)
output=Dense(units=3, activation='softmax')(x)

model_bm=Model(inputs=input, outputs=output)
model_bm.summary()
# Out:
# Model: "model_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_23 (InputLayer)       [(None, 32, 64, 1)]       0
#
#  conv2d_286 (Conv2D)         (None, 32, 64, 64)        640
#
#  conv2d_287 (Conv2D)         (None, 32, 64, 64)        36928
#
#  max_pooling2d_110 (MaxPooli  (None, 16, 32, 64)       0
#  ng2D)
#
#  conv2d_288 (Conv2D)         (None, 16, 32, 128)       73856
#
#  conv2d_289 (Conv2D)         (None, 16, 32, 128)       147584
#
#  max_pooling2d_111 (MaxPooli  (None, 8, 16, 128)       0
#  ng2D)
#
#  conv2d_290 (Conv2D)         (None, 8, 16, 256)        295168
#
#  conv2d_291 (Conv2D)         (None, 8, 16, 256)        590080
#
#  conv2d_292 (Conv2D)         (None, 8, 16, 256)        590080
#
#  max_pooling2d_112 (MaxPooli  (None, 4, 8, 256)        0
#  ng2D)
#
#  conv2d_293 (Conv2D)         (None, 4, 8, 512)         1180160
#
# ...

# %%
model_bm.compile(
    optimizer=tf.keras.optimizers.Adam(0.0001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=tf.keras.metrics.SparseCategoricalAccuracy()
)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_sparse_categorical_accuracy',patience=25,
                                            restore_best_weights=True, mode='max')
history_bm=model_bm.fit(train_dataset_bm, epochs=25, validation_data=(test_dataset_bm),callbacks=[callback])
# Out:
# Epoch 1/25
# 441/441 [==============================] - 18s 38ms/step - loss: 1.0770 - sparse_categorical_accuracy: 0.4268 - val_loss: 1.0667 - val_sparse_categorical_accuracy: 0.4488
# Epoch 2/25
# 441/441 [==============================] - 17s 37ms/step - loss: 1.0506 - sparse_categorical_accuracy: 0.4580 - val_loss: 1.0473 - val_sparse_categorical_accuracy: 0.4629
# Epoch 3/25
# 441/441 [==============================] - 17s 37ms/step - loss: 1.0279 - sparse_categorical_accuracy: 0.4780 - val_loss: 1.0389 - val_sparse_categorical_accuracy: 0.4709
# Epoch 4/25
# 441/441 [==============================] - 17s 37ms/step - loss: 0.9974 - sparse_categorical_accuracy: 0.5044 - val_loss: 1.0163 - val_sparse_categorical_accuracy: 0.4884
# Epoch 5/25
# 441/441 [==============================] - 17s 38ms/step - loss: 0.9557 - sparse_categorical_accuracy: 0.5317 - val_loss: 1.0000 - val_sparse_categorical_accuracy: 0.5026
# Epoch 6/25
# ...

# %%
model_bm.save("/content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/bottom_mask_model")
# Out:
# INFO:tensorflow:Assets written to: /content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/bottom_mask_model/assets

# %%
y_pred=model_bm.predict(np.asarray(x_test_bm))
y_preds=np.argmax(y_pred,axis=1)

# %%
confusion_matrix(y_test_bm,y_preds)
# Out:
# array([[1859,  413,  766],
#        [ 432, 1028,  598],
#        [ 612,  469, 1000]])

# %%
accuracy_score(y_test_bm,y_preds)
# Out:
# 0.5415911940922391

# %%
f1_score(y_test_bm,y_preds, average='weighted')
# Out:
# 0.543948528454551

# %%
print(classification_report(y_test_bm,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.61      0.63      3038
#            1       0.54      0.50      0.52      2058
#            2       0.42      0.48      0.45      2081
#
#     accuracy                           0.54      7177
#    macro avg       0.53      0.53      0.53      7177
# weighted avg       0.55      0.54      0.54      7177

# %% [markdown]
# ## TOP Mask

# %%
train_dataset_tm = train_dataset_tm.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset_tm = test_dataset_tm.batch(BATCH_SIZE)

# %%
input = Input(shape=(32,64,1))
x=Conv2D(filters=64,kernel_size=3, padding='same',activation='relu')(input)
x=Conv2D(filters=64,kernel_size=3, padding='same',activation='relu')(x)
x=MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
x=Conv2D(filters=128,kernel_size=3, padding='same', activation='relu')(x)
x=Conv2D(filters=128,kernel_size=3, padding='same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding= 'same')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)


x=Flatten()(x)
x=Dense(units=4096, activation='relu')(x)
x=Dense(units=4096, activation='relu')(x)
x=Dense(units=1000, activation='relu')(x)
output=Dense(units=3, activation='softmax')(x)


model_tm=Model(inputs=input, outputs=output)
model_tm.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_19 (InputLayer)       [(None, 32, 64, 1)]       0
#
#  conv2d_234 (Conv2D)         (None, 32, 64, 64)        640
#
#  conv2d_235 (Conv2D)         (None, 32, 64, 64)        36928
#
#  max_pooling2d_90 (MaxPoolin  (None, 16, 32, 64)       0
#  g2D)
#
#  conv2d_236 (Conv2D)         (None, 16, 32, 128)       73856
#
#  conv2d_237 (Conv2D)         (None, 16, 32, 128)       147584
#
#  max_pooling2d_91 (MaxPoolin  (None, 8, 16, 128)       0
#  g2D)
#
#  conv2d_238 (Conv2D)         (None, 8, 16, 256)        295168
#
#  conv2d_239 (Conv2D)         (None, 8, 16, 256)        590080
#
#  conv2d_240 (Conv2D)         (None, 8, 16, 256)        590080
#
#  max_pooling2d_92 (MaxPoolin  (None, 4, 8, 256)        0
#  g2D)
#
#  conv2d_241 (Conv2D)         (None, 4, 8, 512)         1180160
#
# ...

# %%
model_tm.compile(
    optimizer=tf.keras.optimizers.Adam(0.0001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=tf.keras.metrics.SparseCategoricalAccuracy()
)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_sparse_categorical_accuracy',patience=25,
                                            restore_best_weights=True)
history_tm=model_tm.fit(train_dataset_tm, epochs=25, validation_data=(test_dataset_tm),callbacks=[callback])
# Out:
# Epoch 1/25
# 441/441 [==============================] - 18s 39ms/step - loss: 0.9349 - sparse_categorical_accuracy: 0.5179 - val_loss: 0.9059 - val_sparse_categorical_accuracy: 0.5318
# Epoch 2/25
# 441/441 [==============================] - 16s 37ms/step - loss: 0.7652 - sparse_categorical_accuracy: 0.6146 - val_loss: 0.8043 - val_sparse_categorical_accuracy: 0.5994
# Epoch 3/25
# 441/441 [==============================] - 16s 37ms/step - loss: 0.7040 - sparse_categorical_accuracy: 0.6643 - val_loss: 0.8076 - val_sparse_categorical_accuracy: 0.6021
# Epoch 4/25
# 441/441 [==============================] - 16s 37ms/step - loss: 0.6453 - sparse_categorical_accuracy: 0.7045 - val_loss: 0.7747 - val_sparse_categorical_accuracy: 0.6426
# Epoch 5/25
# 441/441 [==============================] - 16s 37ms/step - loss: 0.5838 - sparse_categorical_accuracy: 0.7395 - val_loss: 0.8845 - val_sparse_categorical_accuracy: 0.6244
# Epoch 6/25
# ...

# %%
model_tm.save("/content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/top_mask_model")
# Out:
# INFO:tensorflow:Assets written to: /content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/top_mask_model/assets

# %%
y_pred=model_tm.predict(np.asarray(x_test_tm))
y_preds=np.argmax(y_pred,axis=1)

# %%
confusion_matrix(y_test_tm,y_preds)
# Out:
# array([[2349,  389,  300],
#        [ 220, 1236,  602],
#        [ 201,  626, 1254]])

# %%
accuracy_score(y_test_tm,y_preds)
# Out:
# 0.6742371464400168

# %%
f1_score(y_test_tm,y_preds, average='weighted')
# Out:
# 0.6785332002233931

# %%
print(classification_report(y_test_tm,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81      3038
#            1       0.55      0.60      0.57      2058
#            2       0.58      0.60      0.59      2081
#
#     accuracy                           0.67      7177
#    macro avg       0.66      0.66      0.66      7177
# weighted avg       0.69      0.67      0.68      7177

# %%
#!zip -r /content/no_mask.zip /content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/no_mask_model
#from google.colab import files
#files.download("/content/no_mask.zip")

# %%
#!zip -r /content/top_mask.zip /content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/top_mask_model
#from google.colab import files
#files.download("/content/n_mask.zip")

# %%
#!zip -r /content/bottom_mask.zip /content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/bottom_mask_model
#from google.colab import files
#files.download("/content/n_mask.zip")

# %%
## Three Fourths Face

train_dataset_tfm = train_dataset_tfm.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset_tfm = test_dataset_tfm.batch(BATCH_SIZE)

# %%
input = Input(shape=(48,64,1))
x=Conv2D(filters=64,kernel_size=3, padding='same',activation='relu')(input)
x=Conv2D(filters=64,kernel_size=3, padding='same',activation='relu')(x)
x=MaxPool2D(pool_size =2, strides =2, padding ='same')(x)
x=Conv2D(filters=128,kernel_size=3, padding='same', activation='relu')(x)
x=Conv2D(filters=128,kernel_size=3, padding='same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding= 'same')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=256, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)

x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=Conv2D(filters=512, kernel_size=3, padding = 'same', activation='relu')(x)
x=MaxPool2D(pool_size=2, strides=2, padding='same')(x)


x=Flatten()(x)
x=Dense(units=4096, activation='relu')(x)
x=Dense(units=4096, activation='relu')(x)
x=Dense(units=1000, activation='relu')(x)
output=Dense(units=3, activation='softmax')(x)


model_tfm=Model(inputs=input, outputs=output)
model_tfm.summary()
# Out:
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_20 (InputLayer)       [(None, 48, 64, 1)]       0
#
#  conv2d_247 (Conv2D)         (None, 48, 64, 64)        640
#
#  conv2d_248 (Conv2D)         (None, 48, 64, 64)        36928
#
#  max_pooling2d_95 (MaxPoolin  (None, 24, 32, 64)       0
#  g2D)
#
#  conv2d_249 (Conv2D)         (None, 24, 32, 128)       73856
#
#  conv2d_250 (Conv2D)         (None, 24, 32, 128)       147584
#
#  max_pooling2d_96 (MaxPoolin  (None, 12, 16, 128)      0
#  g2D)
#
#  conv2d_251 (Conv2D)         (None, 12, 16, 256)       295168
#
#  conv2d_252 (Conv2D)         (None, 12, 16, 256)       590080
#
#  conv2d_253 (Conv2D)         (None, 12, 16, 256)       590080
#
#  max_pooling2d_97 (MaxPoolin  (None, 6, 8, 256)        0
#  g2D)
#
#  conv2d_254 (Conv2D)         (None, 6, 8, 512)         1180160
#
# ...

# %%
three_fourth_mask[0].shape
# Out:
# (48, 64)

# %%
model_tfm.compile(
    optimizer=tf.keras.optimizers.Adam(0.0001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=tf.keras.metrics.SparseCategoricalAccuracy()
)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=25,
                                            restore_best_weights=True)
history_tfm=model_tfm.fit(train_dataset_tfm, epochs=25, validation_data=(test_dataset_tfm),callbacks=[callback])
# Out:
# Epoch 1/25
# 441/441 [==============================] - 23s 49ms/step - loss: 0.9360 - sparse_categorical_accuracy: 0.5216 - val_loss: 0.9480 - val_sparse_categorical_accuracy: 0.5055
# Epoch 2/25
# 441/441 [==============================] - 21s 48ms/step - loss: 0.7473 - sparse_categorical_accuracy: 0.6435 - val_loss: 0.8056 - val_sparse_categorical_accuracy: 0.6029
# Epoch 3/25
# 441/441 [==============================] - 21s 48ms/step - loss: 0.6668 - sparse_categorical_accuracy: 0.6958 - val_loss: 0.7910 - val_sparse_categorical_accuracy: 0.6277
# Epoch 4/25
# 441/441 [==============================] - 21s 48ms/step - loss: 0.5853 - sparse_categorical_accuracy: 0.7392 - val_loss: 0.8169 - val_sparse_categorical_accuracy: 0.6244
# Epoch 5/25
# 441/441 [==============================] - 21s 48ms/step - loss: 0.5063 - sparse_categorical_accuracy: 0.7780 - val_loss: 0.8204 - val_sparse_categorical_accuracy: 0.6595
# Epoch 6/25
# ...

# %%
model_tfm.save("/content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/bottom_mask_model")
# Out:
# INFO:tensorflow:Assets written to: /content/Facial-Detection-and-Emotion-Classifier/10_Code/03_Model_Checkpoints/bottom_mask_model/assets

# %%
y_pred=model_tfm.predict(np.asarray(x_test_tfm))
y_preds=np.argmax(y_pred,axis=1)

# %%
confusion_matrix(y_test_tfm,y_preds)
# Out:
# array([[2449,  377,  212],
#        [ 197, 1523,  338],
#        [ 209,  837, 1035]])

# %%
accuracy_score(y_test_tfm,y_preds)
# Out:
# 0.6976452556778598

# %%
f1_score(y_test_tfm,y_preds, average='weighted')
# Out:
# 0.6977034663449198

# %%
print(classification_report(y_test_tm,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83      3038
#            1       0.56      0.74      0.64      2058
#            2       0.65      0.50      0.56      2081
#
#     accuracy                           0.70      7177
#    macro avg       0.69      0.68      0.68      7177
# weighted avg       0.71      0.70      0.70      7177

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history.history['val_sparse_categorical_accuracy'],label='No Mask')
plt.plot(range(1,26),history_tfm.history['val_sparse_categorical_accuracy'],label='Three Fourths Mask')
plt.plot(range(1,26),history_tm.history['val_sparse_categorical_accuracy'],label='Top Mask')
plt.plot(range(1,26),history_bm.history['val_sparse_categorical_accuracy'],label='Bottom Mask')


plt.title("Testing Sparse Categorical Accuracy vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history.history['sparse_categorical_accuracy'],label='No Mask')
plt.plot(range(1,26),history_tfm.history['sparse_categorical_accuracy'],label='Three Fourths Mask')
plt.plot(range(1,26),history_tm.history['sparse_categorical_accuracy'],label='Top Mask')
plt.plot(range(1,26),history_bm.history['sparse_categorical_accuracy'],label='Bottom Mask')


plt.title("Training Sparse Categorical Accuracy vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history.history['sparse_categorical_accuracy'],label='Training')
plt.plot(range(1,26),history.history['val_sparse_categorical_accuracy'],label='Testing')



plt.title("No Mask - Sparse Categorical Accuracy vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history_tm.history['sparse_categorical_accuracy'],label='Training')
plt.plot(range(1,26),history_tm.history['val_sparse_categorical_accuracy'],label='Testing')



plt.title("Top Mask - Sparse Categorical Accuracy vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history_bm.history['sparse_categorical_accuracy'],label='Training')
plt.plot(range(1,26),history_bm.history['val_sparse_categorical_accuracy'],label='Testing')



plt.title("Bottom Mask - Sparse Categorical Accuracy vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history_tfm.history['sparse_categorical_accuracy'],label='Training')
plt.plot(range(1,26),history_tfm.history['val_sparse_categorical_accuracy'],label='Testing')



plt.title("Three Fourths Mask - Sparse Categorical Accuracy vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history.history['loss'],label='No Mask')
plt.plot(range(1,26),history_tfm.history['loss'],label='Three Fourths Mask')
plt.plot(range(1,26),history_tm.history['loss'],label='Top Mask')
plt.plot(range(1,26),history_bm.history['loss'],label='Bottom Mask')


plt.title("Training Loss vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history.history['val_loss'],label='No Mask')
plt.plot(range(1,26),history_tfm.history['val_loss'],label='Three Fourths Mask')
plt.plot(range(1,26),history_tm.history['val_loss'],label='Top Mask')
plt.plot(range(1,26),history_bm.history['val_loss'],label='Bottom Mask')


plt.title("Testing Loss vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history.history['loss'],label='Training')
plt.plot(range(1,26),history.history['val_loss'],label='Testing')



plt.title("No Mask - Loss vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history_bm.history['loss'],label='Training')
plt.plot(range(1,26),history_bm.history['val_loss'],label='Testing')



plt.title("Bottom Mask - Loss vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history_tm.history['loss'],label='Training')
plt.plot(range(1,26),history_tm.history['val_loss'],label='Testing')



plt.title("Top Mask - Loss vs Epochs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,26),history_tfm.history['loss'],label='Training')
plt.plot(range(1,26),history_tfm.history['val_loss'],label='Testing')



plt.title("Three Fourths Mask - Loss vs Epochs")
plt.legend()
plt.show()
